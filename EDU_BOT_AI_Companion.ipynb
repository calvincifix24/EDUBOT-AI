# %% [markdown]
# <a href="https://colab.research.google.com/github/calvincifix24/EDUBOT-AI/blob/main/EDU_BOT_AI_Companion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-large")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-large")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
def ask_bot(question):
    inputs = tokenizer(question, return_tensors="pt", padding=True)
    outputs = model.generate(**inputs, max_length=256)
    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer

# %%
question = "Explain Newton's First Law in simple words"
answer = ask_bot(question)
print("EDU-BOT says:", answer)
# Out:
# EDU-BOT says: The first law of motion is the law of the compass

# %%
# !pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.9 MB/s eta 0:00:00
# ...

# %%
def ask_about_pdf(question, context):
    prompt = f"Answer the question based on the following text:\n\n{context}\n\nQuestion: {question}"
    inputs = tokenizer(prompt, return_tensors="pt", max_length=512, truncation=True)
    outputs = model.generate(**inputs, max_new_tokens=150)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
def ask_about_pdf(question, context):
    input_text = f"Context: {context}\n\nQuestion: {question}"
    inputs = tokenizer(input_text, return_tensors="pt", max_length=512, truncation=True)
    outputs = model.generate(**inputs, max_new_tokens=150)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Example question
question = "Summarize the main topic of this document."
short_context = pdf_text[:1000]  # Limits to 1000 characters
answer = ask_about_pdf(question, short_context)
print("EDU-BOT says:", answer)
# Out:
# EDU-BOT says: The ultimate mini guide to help creators, coaches & freelancers grow fast and get paid even with a tiny audience. Inside, you’ll discover 10 plug-and-play AI prompts to crack the Instagram algorithm, create binge- worthy content, attract high-paying clients, and sell digital products on autopilot. Built for beginners. Powered by AI. Designed to make you money.AI Growth Kit – Go Viral & Get Paid (Even with Low Followers)Calvin NivlacAI Growth Kit – Go Viral & Get Paid (Even with Low Followers)Calvin Nivlac 10 Ways to Trigger the Instagram Algorithm

# %%
# !pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 19.7 MB/s eta 0:00:00
# ...

# %%
# 1. Upload PDF
from google.colab import files
uploaded = files.upload()

# 2. Install PyMuPDF
# !pip install -q pymupdf

# 3. Extract text from PDF using PyMuPDF
import fitz  # PyMuPDF

# Check if any file was uploaded
if uploaded:
    pdf_path = list(uploaded.keys())[0]  # Get the first uploaded file
    doc = fitz.open(pdf_path)

    pdf_text = ""
    for page in doc:
        pdf_text += page.get_text()

    doc.close()

    # Print first 1000 characters to verify
    print("PDF Text Preview:\n")
    print(pdf_text[:1000])
else:
    print("❌ No PDF uploaded. Please upload a PDF file.")
# Out:
#      <input type="file" id="files-f34bff7a-fac5-491c-ad82-77607fa9e890" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f34bff7a-fac5-491c-ad82-77607fa9e890">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
